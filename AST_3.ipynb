# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# # Univariate Analysis
# ## Displot

# %%
sns.displot(df.culmen_length_mm)

# %%
sns.displot(df.body_mass_g)

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df.culmen_depth_mm)
# Out:
# <ipython-input-6-4b07ffb4fe44>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_depth_mm)
# <Axes: xlabel='culmen_depth_mm', ylabel='Density'>

# %% [markdown]
# ## Pie Chart

# %%
plt.pie(df.species.value_counts(),[0.02,0.02,0.02],labels=['Adelie','Gentoo','Chinstrap'],autopct='%1.1f%%',shadow=False,colors=['Red','Green','Yellow'])
plt.show()

# %% [markdown]
# ## Barplot

# %%
sns.barplot(x=df.island.value_counts(),y=df.island.value_counts())
# Out:
# <Axes: xlabel='island', ylabel='island'>

# %% [markdown]
# # Bivariate Analysis

# %%
sns.lineplot(x=df.culmen_length_mm,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.lineplot(x=df.culmen_length_mm,y=df.flipper_length_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x=df.culmen_length_mm,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.scatterplot(x=df.culmen_length_mm,y=df.flipper_length_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# # Multivariate Analysis
# ## Pairplot

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-21-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# # Missing Values

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %% [markdown]
# # Finding and Replacing Outliers

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.species=le.fit_transform(df.species)
df.island=le.fit_transform(df.island)
df.sex=le.fit_transform(df.sex)
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2              39.1             18.7              181.0
# 1        0       2              39.5             17.4              186.0
# 2        0       2              40.3             18.0              195.0
# 3        0       2               NaN              NaN                NaN
# 4        0       2              36.7             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    2
# 1       3800.0    1
# 2       3250.0    1
# 3          NaN    3
# 4       3450.0    1

# %% [markdown]
# # Correlation of independent variables with target

# %%
df.corr().sex.sort_values(ascending=False)
# Out:
# sex                  1.000000
# body_mass_g          0.347376
# culmen_depth_mm      0.322860
# culmen_length_mm     0.269434
# flipper_length_mm    0.197440
# island               0.043476
# species             -0.010379
# Name: sex, dtype: float64

# %% [markdown]
# # Dependent and Independent Variables

# %%
X=df.drop(columns=['sex'],axis=1)
X.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2              39.1             18.7              181.0
# 1        0       2              39.5             17.4              186.0
# 2        0       2              40.3             18.0              195.0
# 3        0       2               NaN              NaN                NaN
# 4        0       2              36.7             19.3              193.0
#
#    body_mass_g
# 0       3750.0
# 1       3800.0
# 2       3250.0
# 3          NaN
# 4       3450.0

# %%
Y=df.sex
Y=pd.DataFrame(Y,columns=['sex'])
Y.head()
# Out:
#    sex
# 0    2
# 1    1
# 2    1
# 3    3
# 4    1

# %% [markdown]
# # Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_scaled=pd.DataFrame(sc.fit_transform(X),columns=X.columns)
X_scaled.head()
# Out:
#     species    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0 -1.029802  1.844076         -0.884499         0.785449          -1.418347
# 1 -1.029802  1.844076         -0.811126         0.126188          -1.062250
# 2 -1.029802  1.844076         -0.664380         0.430462          -0.421277
# 3 -1.029802  1.844076               NaN              NaN                NaN
# 4 -1.029802  1.844076         -1.324737         1.089724          -0.563715
#
#    body_mass_g
# 0    -0.564142
# 1    -0.501703
# 2    -1.188532
# 3          NaN
# 4    -0.938776

# %% [markdown]
# # Train and Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.2,random_state=0)

# %% [markdown]
# # Checking shape of the train and test split
# ## Train

# %%
X_train.shape
# Out:
# (275, 6)

# %%
Y_train.shape
# Out:
# (275, 1)

# %% [markdown]
# ## Test

# %%
X_test.shape
# Out:
# (69, 6)

# %%
Y_test.shape
# Out:
# (69, 1)
